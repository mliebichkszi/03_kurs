# %% [markdown]
# # Listen
#
# ## 🎯 Lernziele
#
# In dieser Lektion lernst du nochmals mit Listen zu arbeiten, damit wir im nächsten Schritt das Nim-Spiel programmieren können.
#
# ## 📝 Listen erstellen
# ([Back to top](#Table-of-Contents))
#
# In der Prüfung hast du 2 Listen erstellt. 1 Liste für Fragen, die andere für Antworten.

# %%
quiz_fragen= [
  "In welchem Jahr startete die Kanti Zimmerberg?",
  "Wie alt ist der älteste Baum der Erde?",
  "Wie lange braucht die Erde, um die Sonne zu umkreisen?"
]

quiz_antworten = [2020, 4853, 365]

print(quiz_fragen)
print(quiz_antworten)

# %% [markdown]
# Wie in anderen Programmiersprachen auch, werden Listen mit eckigen Klammern eröffnet `[ ]`. Jedes Element in der Liste wird mit Kommata getrennt. Im obigen Beispiel wurde ein Zeilenumbruch zwischen den Fragen hinzugefügt, damit die Liste leichter lesbar ist. Das ist aber nicht zwingend notwendig.
#
# ### 👈 Listen-Elemente auswählen
# ([Back to top](#Table-of-Contents))
#
# Wenn du ein einzelnes Element aus einer Liste auswählen willst, musst du den **Index** (die Position des Objekts in der Liste) angeben:

# %%
quiz_fragen= [
  "In welchem Jahr startete die Kanti Zimmerberg?",
  "Wie alt ist der älteste Baum der Erde?",
  "Wie lange braucht die Erde, um die Sonne zu umkreisen?"
]

erste_frage = quiz_fragen[0]

print(erste_frage)

# %% [markdown]
# Beachte, dass Listen mit der Position `0` beginnen!

# %% [markdown]
# Erstelle eine Liste mit 4 Elementen. Weise einer Variablen das 2 Element zu und `print`e den Variablen-Inhalt.

# %% [markdown]
# ### ✍️ Listen bearbeiten
# ([Back to top](#Table-of-Contents))
#
# Wie bei allen Datentypen stellt Python Methoden für Listen zur Verfügung. So kannst du beispielsweise ganz einfach Listen sortieren (`sort`) oder zählen, wie oft ein Element in der Liste vorkommt (`count`), die Liste umkehren (`reverse`) oder Elemente an bestimmten Positionen einfügen (`insert`). Es lohnt sich, in der offiziellen Python-Dokumentation die Methoden anzuschauen: [Python Dokumentation](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists)
#
# Du kannst die Methode `len` verwenden. Diese kennst du ja bereits schon vom Datentyp String:

# %%
pizza_zutaten = ["Teig", "Tomatensauce", "Käse"]
anzahl_zutaten = len(pizza_zutaten)

print(anzahl_zutaten)

# %% [markdown]
# Wir werden jetzt Elemente ändern, hinzufügen und entfernen. Andere Listen-[Methoden](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists) kannst du noch selbst ausprobieren.
#
# ### Elemente ändern
# Ein Element kannst du ändern, indem du das Element überschreibst. Dazu rufst du es mit seinem Index auf.
# Behebe die Fehler in den folgenden zwei Zellen:

# %%
# Beispiel 1:

lieblings_cookies = []

lieblings_cookies[0] = "Schokolade"

print(lieblings_cookies)

# %%
# Beispiel 2:

lieblings_tiere = ["Pinguin", "Katze"]

lieblings_tiere[2] = "Hund"

print(lieblings_tiere)

# %% [markdown]
# ### Elemente hinzufügen
#
# Mit `.append()` kannst du Elemente hinzufügen.
# Beispiel:

# %%
lieblings_cookies = []

lieblings_cookies.append("Waldbeeren")

print(lieblings_cookies)

# %% [markdown]
# Versuche es gleich selbst. Füge ein Tier zur Liste hinzu:

# %%
lieblings_tiere = ["Pinguin", "Katze"]

# 👇 Dein Code Start




# 👆 Dein Code Ende

print(lieblings_tiere)

# %% [markdown]
# Jetzt erstellen wir eine grössere Liste, eine Shopping-Liste.
#
# - Erstelle eine Shopping-Liste
# - Erstelle eine Funktion `element_hinzufuegen()`.
#   In der Funktion soll die Person nach einem neuen Element gefragt werden.     Speichere die Antwort in einer Variablen ab (z.B., `neues_element`).
# - Füge das Element zur Shopping-Liste hinzu.
# - Erstelle ausserhalb der Funktion eine while-Schleife.
#   Führe die Funktion `element_hinzufuegen()` innerhalb der Schleife aus.
#   Frage die Person, ob sie weitere Elemente hinzufuegen will. Falls nicht, soll die Schleife abgebrochen werden.
# - Als Abschluss soll die Shopping-Liste angezeigt werden.
# - Teste dein Programm.

# %%
# 👇 Dein Code

# %% [markdown]
# To kannst auch auf andere Art eine Liste erweitern, z.B. mit `.extend()` um 2 Listen zu kombinieren. Oder mit `.insert()`, um Elemente an bestimmten Positionen einzupflegen.
#
#
# ### Elemente löschen
#
# Du kannst mit `.remove()` Elemente löschen:

# %%
lieblings_tiere = ["Maus", "Katze", "Seehund", "Hase", "Hund", "Maulwurf", "Seehund"]

lieblings_tiere.remove("Hase")

print(lieblings_tiere)

# %% [markdown]
# Lass den Code laufen. Ersetze `lieblings_tiere.remove("Hase")` mit`lieblings_tiere.remove("Seehund")`. Was passiert?
#
# Es wird nur der erste Seehund aus der Liste entfernt. Vielleicht möchtest du aber den zweiten oder beide aus der Liste entfernen.
#
# In diesem Fall ist `.pop()` die bessere Wahl. Mit dieser Methode wählst du die zu entfernende Position:

# %%
lieblings_tiere = ["Maus", "Katze", "Seehund", "Hase", "Hund", "Maulwurf", "Seehund"]

lieblings_tiere.pop(6)

print(lieblings_tiere)

# %% [markdown]
# Jetzt werden wir `.remove()` und `.pop()` anwenden.
#
# - Schreibe eine Funktion `element_entfernen()`.
#   Erstelle eine Variable(z.B., `wahl`) und weise sie dem Input der Person zu. Die Person soll nach dem zu entfernenden Element gefragt werden.
#   Entferne das Element aus der Shopping-Liste.
# - Erstelle wiederum eine Schleife.
#   Führe `element_entfernen()` aus.
# - Frage die Person, ob sie weitere Elemente entfernen will, falls nicht, soll die Schleife beendet werden.
# - Am Schluss soll die Shopping-Liste angezeigt werden.
# - Teste dein Programm.

# %%
shopping_list = ["Salat", "Tomaten", "Tofu", "Mozarella", "Blumen", "Zahnpasta"]

# 👇 Dein Code

# %% [markdown]
# Du kannst nur Elemente mit `.remove()` entfernen, die in der Liste sind, ansonsten erhältst du einen `ValueError`.
#
# Es wäre schade, wenn das Programm abbrechen würde, nur weil die Person ein nicht vorhandenes Element nennt. Deshalb sollten wir eine Fehlerbehandlung machen.
#
# Der **Membership Operator** `in` hilft hier. Er prüft, ob ein Element `in` einem Objekt wie einer Liste vorhanden ist.

# %%
pizza_zutaten = ["Teig", "Tomatensauce", "Käse"]

if "Käse" in pizza_zutaten:
  print("Die Pizza enthält Milchprodukte")
else:
  print("Die Pizza enthält keine Milchprodukte!")

# %% [markdown]
# Gehe zu deinem Code mit der Shopping-Liste zurück und verwende die `remove_item()` Funktion. Stelle sicher, dass nur Elemente, die auch in der Liste vorhanden sind, entfernt werden können.

# %% [markdown]
# ### 🏡 übung
#
# Du hast in dieser Lektion den Datentyp **list** nochmals kennengelernt.
#
# Jetzt kannst du ein **To-do Programm** schreiben. Im Moment wird das Programm vergesslich sein - bei jeder Ausführung wird die To-do Liste wieder voll sein. Später lernen wir Datenbanken kennen und können die Werte dort permanent abspeichern.
#
# 1. Erstelle eine Variable, die die To-dos enthalten wird. Zu Beginn ist die Liste leer.
# 2. Erstelle eine Funktion, mit der man Elemente zur Liste hinzufügen kann.
# 3. Erstelle eine 2. Funktion, mit der man Elemente entfernen kann, indem man den Index des Elements angibt. Verwende `.pop()` statt `.remove()`. Verwende eine längere Bedingung mit `elif` um zu prüfen ob der Input numerisch ist. Prüfe auch, ob der Input grösser gleich `0` **and** kleiner als die Listenlänge ist. *Vergiss nicht: User-Inputs sind vom Datentyp String, du musst die Inputs also noch in Integers umwandeln. Verwende `len()` um die Listenlänge zu ermitteln.
# 4. Erstelle eine Schleife, in der gefragt wird, ob ein To-do hinzugefügt, gelöscht oder das Programm beendet werden soll. Je nach Input soll dann hinzugefügt, gelöscht oder das Programm verlassen werden.
# 5. Nach jeder Änderung soll die Liste ausgegeben werden.
